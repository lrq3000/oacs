# %% [markdown]
# DEBUG NOTEBOOK
# ====
# This page clusters together a few test codes to check that the software (and more specifically the infrastracture) is correctly working.
#
# You should not use this notebook except if you are a software developper.

# %%
print "hello world!\n"*5
# Out:
# hello world!
# hello world!
# hello world!
# hello world!
# hello world!

# %%
import loaddata
reload(loaddata)
import pprint
types = loaddata.JsonParser.loadconfig('types.txt')
data = loaddata.JsonParser.loadconfig('data.txt', True)
print('Data:')
print(pprint.pformat(data))
random.seed()
print('SVTime for one random sample: %s' % data[random.randint(1, len(data))]['svtime']['value'])
print
print('Types:')
print(pprint.pformat(types))
print('Cheater feature type: %s' % types['cheater']['type'])
# Out:
# Data:
# [{u'armor': {u'key': u'armor', u'value': 0},
#   u'cheater': {u'key': u'cheater', u'value': 0},
#   u'fragsinarow': {u'key': u'fragsinarow', u'value': 0},
#   u'framerepeat': {u'key': u'framerepeat', u'value': 0},
#   u'playerid': {u'key': u'playerid', u'value': 0},
#   u'reactiontime': {u'key': u'reactiontime', u'value': 0},
#   u'svtime': {u'key': u'svtime', u'value': 0},
#   u'timestamp': {u'key': u'timestamp', u'value': 0}},
#  {u'armor': {u'key': u'armor', u'value': 0},
#   u'cheater': {u'key': u'cheater', u'value': 0},
#   u'fragsinarow': {u'key': u'fragsinarow', u'value': 0},
#   u'framerepeat': {u'key': u'framerepeat', u'value': 15},
#   u'playerid': {u'key': u'playerid', u'value': 2},
#   u'reactiontime': {u'key': u'reactiontime', u'value': 9520},
#   u'svtime': {u'key': u'svtime', u'value': 9520},
#   u'timestamp': {u'key': u'timestamp', u'value': 1363438047}},
#  {u'armor': {u'key': u'armor', u'value': 0},
#   u'cheater': {u'key': u'cheater', u'value': 1},
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import oacs.main
reload(oacs.main)
runner = oacs.main.main(['--script'])
import pprint
print
print("Printing all items/parsers loaded into runner")
print(runner.__dict__)
print
print("Testing with multiple input parsers")
pprint.pprint(runner.inputparser['interframeparser'].config.config)
# Out:
# Printing all items/parsers loaded into runner
# {u'inputparser': {u'interframeparser': <oacs.inputparser.interframeparser.InterframeParser object at 0x0000000007174E80>, u'jsonparser': <oacs.inputparser.jsonparser.JsonParser object at 0x00000000070F7630>}, 'config': <oacs.configparser.ConfigParser object at 0x0000000007174FD0>}
# Testing with multiple input parsers
# {
# u'classes': {u'inputparser': [u'InterframeParser', u'JsonParser']},
#  u'help': u'hihi',
#  'input': None,
#  'interactive': False,
#  u'optimization': {u'post': {u'crossval': {u'variables': [u'X',
#                                                           u'Y',
#                                                           u'Theta',
#                                                           u'Lambda',
#                                                           u'K']}}},
#  'script': True,
#  u'test': u'a test value',
#  u'test2': u'N'}

# %%
# %load_ext autoreload
# %autoreload 2
import oacs.main
reload(oacs.main)
runner = oacs.main.main(['--script'])
import pprint
print("Check all items/parsers loaded into runner")
print(runner.__dict__)
print("Checking that the submodules get a reference to the same config as the toplevel (so if either one modify the config, it is propagated everywhere)")
print(runner.inputparser.config.config is runner.config.config)
runner.config.config["help"] = "test1"
print(runner.inputparser.config.config["help"])
runner.inputparser.config.config["help"] = "test2"
print(runner.config.config["help"])
# Out:
# Check all items/parsers loaded into runner
# {u'inputparser': <oacs.inputparser.interframeparser.InterframeParser object at 0x000000000719CFD0>, 'config': <oacs.configparser.ConfigParser object at 0x000000000719CF28>}
# Checking that the submodules get a reference to the same config as the toplevel (so if either one modify the config, it is propagated everywhere)
# True
# test1
# test2

# %%
# %load_ext autoreload
# %autoreload 2
import oacs.main
reload(oacs.main)
runner = oacs.main.main(['--script'])
import pprint
print("Check all items/parsers loaded into runner, while trying to load ALL parsers")
print(runner.__dict__)
pprint.pprint(runner.inputparser['interframeparser'].config.config)
# Out:
# [u'interframeparser', u'jsonparser']
# Check all items/parsers loaded into runner, while trying to load ALL parsers
# {u'inputparser': {'interframeparser': <oacs.inputparser.interframeparser.InterframeParser object at 0x000000000719C048>, 'jsonparser': <oacs.inputparser.jsonparser.JsonParser object at 0x000000000719CB70>}, 'config': <oacs.configparser.ConfigParser object at 0x000000000719C9E8>}
# {
# u'classes': {u'inputparser': u'all'},
#  u'help': u'hihi',
#  'input': None,
#  'interactive': False,
#  u'optimization': {u'post': {u'crossval': {u'variables': [u'X',
#                                                           u'Y',
#                                                           u'Theta',
#                                                           u'Lambda',
#                                                           u'K']}}},
#  'script': True,
#  u'test': u'a test value',
#  u'test2': u'N'}

# %%
[obj for obj in [getattr(random, name) for name in dir(random)] if isinstance(obj, type)]
# Out:
# [mtrand.RandomState, numpy.testing.nosetester.NoseTester]
